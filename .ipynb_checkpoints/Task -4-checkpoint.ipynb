# %% [markdown]
# # TASK-4 Advertising

# %%
import pandas as pd

# %%
adv=pd.read_csv(r'advertising.csv')

# %%
adv.head(10)
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9
# 5    8.7   48.9       75.0    7.2
# 6   57.5   32.8       23.5   11.8
# 7  120.2   19.6       11.6   13.2
# 8    8.6    2.1        1.0    4.8
# 9  199.8    2.6       21.2   15.6

# %%
adv.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
adv.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
adv.shape
# Out:
# (200, 4)

# %%
import seaborn as sns

# %%
sns.pairplot(adv, x_vars=['TV', 'Newspaper', 'Radio'], y_vars='Sales')

# %%
x=adv[['TV', 'Newspaper', 'Radio']]
y=adv['Sales']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
lr=LinearRegression()
lr.fit(x,y)
# Out:
# LinearRegression()

# %%
x_test_pre = lr.predict(x_test)

# %%
x_test_pre
# Out:
# array([14.73822063, 10.94160634, 20.73265903, 19.53008343, 19.49216302,
#        11.64919966, 20.38554445, 12.47673434, 21.68517626, 16.57668108,
#         7.17325114,  7.99360692, 18.87221072, 18.10675693, 20.88243422,
#         9.63019994, 19.31996936, 21.22097209, 16.35231896, 14.71726516,
#        16.4474296 , 18.13231302, 10.19471067, 18.10414656, 24.94140428,
#        23.84503494,  7.10548951, 18.24477648, 15.01773541, 17.84885818,
#         8.30485298, 21.24042066,  7.40087704,  6.01090333, 11.11990058,
#        16.91511512, 11.45948342, 11.26824775,  6.09147928, 15.73518229])

# %%
y_test
# Out:
# 177    16.7
# 143    10.4
# 184    17.6
# 53     21.2
# 27     20.9
# 80     11.8
# 15     22.4
# 115    12.6
# 188    20.9
# 45     16.1
# 106     7.2
# 132     5.7
# 23     20.5
# 187    17.3
# 52     22.6
# 166     8.0
# 25     17.0
# 0      22.1
# 64     16.0
# 179    17.6
# 167    17.2
# 81     17.3
# 29     10.5
# 21     17.5
# 98     25.4
# 36     25.4
# 195     7.6
# 113    20.9
# 87     16.0
# 41     17.1
# 182     8.7
# 169    20.0
# 119     6.6
# 192     5.9
# 51     10.7
# 95     16.9
# 144    12.3
# 1      10.4
# 155     3.2
# 89     16.7
# Name: Sales, dtype: float64

# %%
res=pd.DataFrame({'Original values':y_test,'Predicted values':x_test_pre})

# %%
import matplotlib.pyplot as plt

# %%
sns.lmplot(x='Original values',y='Predicted values',data = res)
